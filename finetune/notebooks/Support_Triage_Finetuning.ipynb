# %%
# !pip install unsloth wandb
# Out:
# Collecting unsloth
#   Downloading unsloth-2026.9.5-py3-none-any.whl.metadata (81 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.0/81.0 kB 4.1 MB/s eta 0:00:00
# Requirement already satisfied: wandb in /usr/local/lib/python3.13/dist-packages (0.28.1)
# Collecting unsloth_zoo>=2026.9.4 (from unsloth)
#   Downloading unsloth_zoo-2026.9.4-py3-none-any.whl.metadata (33 kB)
# Requirement already satisfied: wheel>=0.42.0 in /usr/local/lib/python3.13/dist-packages (from unsloth) (0.48.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.13/dist-packages (from unsloth) (26.3)
# Requirement already satisfied: torch<2.13.0,>=2.4.0 in /usr/local/lib/python3.13/dist-packages (from unsloth) (2.11.0+cu128)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.13/dist-packages (from unsloth) (0.26.0+cu128)
# Requirement already satisfied: numpy in /usr/local/lib/python3.13/dist-packages (from unsloth) (2.1.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.13/dist-packages (from unsloth) (4.67.3)
# Requirement already satisfied: psutil in /usr/local/lib/python3.13/dist-packages (from unsloth) (5.9.5)
# Collecting tyro (from unsloth)
#   Downloading tyro-1.0.16-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.13/dist-packages (from unsloth) (5.29.6)
# Collecting xformers>=0.0.27.post2 (from unsloth)
#   Downloading xformers-0.0.35-py39-none-manylinux_2_28_x86_64.whl.metadata (1.2 kB)
# Collecting bitsandbytes!=0.46.0,!=0.48.0,>=0.45.5 (from unsloth)
#   Downloading bitsandbytes-0.50.2-py3-none-manylinux_2_24_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: triton>=3.0.0 in /usr/local/lib/python3.13/dist-packages (from unsloth) (3.6.0)
# Requirement already satisfied: sentencepiece>=0.2.0 in /usr/local/lib/python3.13/dist-packages (from unsloth) (0.2.2)
# Collecting datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1 (from unsloth)
#   Downloading datasets-4.3.0-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: accelerate>=0.34.1 in /usr/local/lib/python3.13/dist-packages (from unsloth) (1.14.0)
# Requirement already satisfied: peft!=0.11.0,>=0.18.0 in /usr/local/lib/python3.13/dist-packages (from unsloth) (0.20.0)
# Requirement already satisfied: huggingface_hub>=0.34.0 in /usr/local/lib/python3.13/dist-packages (from unsloth) (1.29.0)
# Collecting hf_transfer (from unsloth)
#   Downloading hf_transfer-0.1.9-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.7 kB)
# Requirement already satisfied: diffusers in /usr/local/lib/python3.13/dist-packages (from unsloth) (0.40.0)
# Collecting transformers!=4.52.0,!=4.52.1,!=4.52.2,!=4.52.3,!=4.53.0,!=4.54.0,!=4.55.0,!=4.55.1,!=4.57.0,!=4.57.4,!=4.57.5,!=5.0.0,!=5.1.0,<=5.5.0,>=4.51.3 (from unsloth)
#   Downloading transformers-5.5.0-py3-none-any.whl.metadata (32 kB)
# Collecting trl!=0.19.0,<=0.24.0,>=0.18.2 (from unsloth)
#   Downloading trl-0.24.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: typer>=0.12.0 in /usr/local/lib/python3.13/dist-packages (from unsloth) (0.27.2)
# Requirement already satisfied: pydantic in /usr/local/lib/python3.13/dist-packages (from unsloth) (2.13.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.13/dist-packages (from unsloth) (6.0.3)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.13/dist-packages (from unsloth) (1.6.0)
# Collecting structlog>=24.1.0 (from unsloth)
#   Downloading structlog-26.1.0-py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: click>=8.0 in /usr/local/lib/python3.13/dist-packages (from unsloth) (8.5.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.13/dist-packages (from unsloth) (13.9.4)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.13/dist-packages (from wandb) (4.11.7)
# Requirement already satisfied: requests<3,>=2.0.0 in /usr/local/lib/python3.13/dist-packages (from wandb) (2.32.4)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /usr/local/lib/python3.13/dist-packages (from wandb) (2.68.1)
# Requirement already satisfied: typing-extensions<5,>=4.8 in /usr/local/lib/python3.13/dist-packages (from wandb) (4.16.0)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.13/dist-packages (from accelerate>=0.34.1->unsloth) (0.8.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.13/dist-packages (from datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth) (3.32.5)
# Requirement already satisfied: pyarrow>=21.0.0 in /usr/local/lib/python3.13/dist-packages (from datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth) (23.0.1)
# Collecting dill<0.4.1,>=0.3.0 (from datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth)
#   Downloading dill-0.4.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.13/dist-packages (from datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth) (2.2.3)
# Requirement already satisfied: httpx<1.0.0 in /usr/local/lib/python3.13/dist-packages (from datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth) (0.28.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.13/dist-packages (from datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth) (4.0.1)
# Collecting multiprocess<0.70.17 (from datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth)
#   Downloading multiprocess-0.70.16-py312-none-any.whl.metadata (7.2 kB)
# Collecting fsspec<=2025.9.0,>=2023.1.0 (from fsspec[http]<=2025.9.0,>=2023.1.0->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth)
#   Downloading fsspec-2025.9.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: hf-xet<2.0.0,>=1.5.2 in /usr/local/lib/python3.13/dist-packages (from huggingface_hub>=0.34.0->unsloth) (1.6.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.13/dist-packages (from pydantic->unsloth) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.5 in /usr/local/lib/python3.13/dist-packages (from pydantic->unsloth) (2.46.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.13/dist-packages (from pydantic->unsloth) (0.4.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.13/dist-packages (from requests<3,>=2.0.0->wandb) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.13/dist-packages (from requests<3,>=2.0.0->wandb) (3.19)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.13/dist-packages (from requests<3,>=2.0.0->wandb) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.13/dist-packages (from requests<3,>=2.0.0->wandb) (2026.7.22)
# Requirement already satisfied: setuptools<82 in /usr/local/lib/python3.13/dist-packages (from torch<2.13.0,>=2.4.0->unsloth) (80.10.2)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.13/dist-packages (from torch<2.13.0,>=2.4.0->unsloth) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.13/dist-packages (from torch<2.13.0,>=2.4.0->unsloth) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.13/dist-packages (from torch<2.13.0,>=2.4.0->unsloth) (3.1.6)
# Requirement already satisfied: cuda-toolkit==12.8.1 in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch<2.13.0,>=2.4.0->unsloth) (12.8.1)
# Requirement already satisfied: cuda-bindings<13,>=12.9.4 in /usr/local/lib/python3.13/dist-packages (from torch<2.13.0,>=2.4.0->unsloth) (12.9.7)
# Requirement already satisfied: nvidia-cudnn-cu12==9.19.0.56 in /usr/local/lib/python3.13/dist-packages (from torch<2.13.0,>=2.4.0->unsloth) (9.19.0.56)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.13/dist-packages (from torch<2.13.0,>=2.4.0->unsloth) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.28.9 in /usr/local/lib/python3.13/dist-packages (from torch<2.13.0,>=2.4.0->unsloth) (2.28.9)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.13/dist-packages (from torch<2.13.0,>=2.4.0->unsloth) (3.4.5)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch<2.13.0,>=2.4.0->unsloth) (12.8.4.1)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch<2.13.0,>=2.4.0->unsloth) (12.8.90)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch<2.13.0,>=2.4.0->unsloth) (11.3.3.83)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch<2.13.0,>=2.4.0->unsloth) (1.13.1.3)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch<2.13.0,>=2.4.0->unsloth) (12.8.90)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch<2.13.0,>=2.4.0->unsloth) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch<2.13.0,>=2.4.0->unsloth) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch<2.13.0,>=2.4.0->unsloth) (12.5.8.93)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch<2.13.0,>=2.4.0->unsloth) (12.8.93)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch<2.13.0,>=2.4.0->unsloth) (12.8.93)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch<2.13.0,>=2.4.0->unsloth) (12.8.90)
# Requirement already satisfied: regex>=2025.10.22 in /usr/local/lib/python3.13/dist-packages (from transformers!=4.52.0,!=4.52.1,!=4.52.2,!=4.52.3,!=4.53.0,!=4.54.0,!=4.55.0,!=4.55.1,!=4.57.0,!=4.57.4,!=4.57.5,!=5.0.0,!=5.1.0,<=5.5.0,>=4.51.3->unsloth) (2025.11.3)
# Collecting tokenizers<=0.23.0,>=0.22.0 (from transformers!=4.52.0,!=4.52.1,!=4.52.2,!=4.52.3,!=4.53.0,!=4.54.0,!=4.55.0,!=4.55.1,!=4.57.0,!=4.57.4,!=4.57.5,!=5.0.0,!=5.1.0,<=5.5.0,>=4.51.3->unsloth)
#   Downloading tokenizers-0.22.2-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.3 kB)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.13/dist-packages (from typer>=0.12.0->unsloth) (1.5.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.13/dist-packages (from typer>=0.12.0->unsloth) (0.0.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.13/dist-packages (from rich->unsloth) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.13/dist-packages (from rich->unsloth) (2.21.0)
# Collecting torchao>=0.13.0 (from unsloth_zoo>=2026.9.4->unsloth)
#   Downloading torchao-0.18.0-cp310-abi3-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (21 kB)
# Collecting cut_cross_entropy (from unsloth_zoo>=2026.9.4->unsloth)
#   Downloading cut_cross_entropy-25.1.1-py3-none-any.whl.metadata (9.3 kB)
# Requirement already satisfied: pillow in /usr/local/lib/python3.13/dist-packages (from unsloth_zoo>=2026.9.4->unsloth) (11.3.0)
# Collecting msgspec (from unsloth_zoo>=2026.9.4->unsloth)
#   Downloading msgspec-0.21.1-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (5.8 kB)
# Requirement already satisfied: importlib_metadata in /usr/local/lib/python3.13/dist-packages (from diffusers->unsloth) (9.0.1)
# Requirement already satisfied: docstring-parser>=0.16 in /usr/local/lib/python3.13/dist-packages (from tyro->unsloth) (0.18.0)
# Requirement already satisfied: typeguard>=4.0.0 in /usr/local/lib/python3.13/dist-packages (from tyro->unsloth) (4.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.13/dist-packages (from cuda-bindings<13,>=12.9.4->torch<2.13.0,>=2.4.0->unsloth) (1.8.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.13/dist-packages (from fsspec[http]<=2025.9.0,>=2023.1.0->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth) (3.14.3)
# Requirement already satisfied: anyio in /usr/local/lib/python3.13/dist-packages (from httpx<1.0.0->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth) (4.14.2)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.13/dist-packages (from httpx<1.0.0->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.13/dist-packages (from httpcore==1.*->httpx<1.0.0->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth) (0.16.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.13/dist-packages (from markdown-it-py>=2.2.0->rich->unsloth) (0.1.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.13/dist-packages (from sympy>=1.13.3->torch<2.13.0,>=2.4.0->unsloth) (1.3.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.13/dist-packages (from importlib_metadata->diffusers->unsloth) (4.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.13/dist-packages (from jinja2->torch<2.13.0,>=2.4.0->unsloth) (3.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.13/dist-packages (from pandas->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.13/dist-packages (from pandas->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.13/dist-packages (from pandas->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth) (2026.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth) (2.7.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.13/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.13/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth) (1.24.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.13/dist-packages (from python-dateutil>=2.8.2->pandas->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth) (1.17.0)
# Downloading unsloth-2026.9.5-py3-none-any.whl (23.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.0/23.0 MB 52.2 MB/s eta 0:00:00
# Downloading bitsandbytes-0.50.2-py3-none-manylinux_2_24_x86_64.whl (43.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.1/43.1 MB 17.8 MB/s eta 0:00:00
# Downloading datasets-4.3.0-py3-none-any.whl (506 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 506.8/506.8 kB 15.2 MB/s eta 0:00:00
# Downloading structlog-26.1.0-py3-none-any.whl (73 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.8/73.8 kB 5.8 MB/s eta 0:00:00
# Downloading transformers-5.5.0-py3-none-any.whl (10.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 78.1 MB/s eta 0:00:00
# Downloading trl-0.24.0-py3-none-any.whl (423 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 423.1/423.1 kB 24.7 MB/s eta 0:00:00
# Downloading unsloth_zoo-2026.9.4-py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 72.0 MB/s eta 0:00:00
# Downloading xformers-0.0.35-py39-none-manylinux_2_28_x86_64.whl (3.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 81.2 MB/s eta 0:00:00
# Downloading hf_transfer-0.1.9-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 64.8 MB/s eta 0:00:00
# Downloading tyro-1.0.16-py3-none-any.whl (216 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 216.9/216.9 kB 18.7 MB/s eta 0:00:00
# Downloading dill-0.4.0-py3-none-any.whl (119 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.7/119.7 kB 5.0 MB/s eta 0:00:00
# Downloading fsspec-2025.9.0-py3-none-any.whl (199 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.3/199.3 kB 17.1 MB/s eta 0:00:00
# Downloading multiprocess-0.70.16-py312-none-any.whl (146 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 146.7/146.7 kB 9.6 MB/s eta 0:00:00
# Downloading tokenizers-0.22.2-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 64.8 MB/s eta 0:00:00
# Downloading torchao-0.18.0-cp310-abi3-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (3.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 62.9 MB/s eta 0:00:00
# Downloading cut_cross_entropy-25.1.1-py3-none-any.whl (22 kB)
# Downloading msgspec-0.21.1-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (225 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 225.1/225.1 kB 10.8 MB/s eta 0:00:00
# Installing collected packages: torchao, structlog, msgspec, hf_transfer, fsspec, dill, tyro, multiprocess, tokenizers, datasets, xformers, transformers, cut_cross_entropy, bitsandbytes, trl, unsloth_zoo, unsloth
#   Attempting uninstall: torchao
#     Found existing installation: torchao 0.10.0
#     Uninstalling torchao-0.10.0:
#       Successfully uninstalled torchao-0.10.0
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2025.12.0
#     Uninstalling fsspec-2025.12.0:
#       Successfully uninstalled fsspec-2025.12.0
#   Attempting uninstall: dill
#     Found existing installation: dill 0.4.1
#     Uninstalling dill-0.4.1:
#       Successfully uninstalled dill-0.4.1
#   Attempting uninstall: multiprocess
#     Found existing installation: multiprocess 0.70.19
#     Uninstalling multiprocess-0.70.19:
#       Successfully uninstalled multiprocess-0.70.19
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.23.1
#     Uninstalling tokenizers-0.23.1:
#       Successfully uninstalled tokenizers-0.23.1
#   Attempting uninstall: datasets
#     Found existing installation: datasets 4.8.5
#     Uninstalling datasets-4.8.5:
#       Successfully uninstalled datasets-4.8.5
#   Attempting uninstall: transformers
#     Found existing installation: transformers 5.16.1
#     Uninstalling transformers-5.16.1:
#       Successfully uninstalled transformers-5.16.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2025.12.0 requires fsspec==2025.12.0, but you have fsspec 2025.9.0 which is incompatible.
# Successfully installed bitsandbytes-0.50.2 cut_cross_entropy-25.1.1 datasets-4.3.0 dill-0.4.0 fsspec-2025.9.0 hf_transfer-0.1.9 msgspec-0.21.1 multiprocess-0.70.16 structlog-26.1.0 tokenizers-0.22.2 torchao-0.18.0 transformers-5.5.0 trl-0.24.0 tyro-1.0.16 unsloth-2026.9.5 unsloth_zoo-2026.9.4 xformers-0.0.35

# %%
# !find /content -maxdepth 3 -type f | head -50
# Out:
# /content/.config/.last_update_check.json
# /content/.config/gce
# /content/.config/hidden_gcloud_config_universe_descriptor_data_cache_configs.db
# /content/.config/active_config
# /content/.config/default_configs.db
# /content/.config/.last_opt_in_prompt.yaml
# /content/.config/.last_survey_prompt.yaml
# /content/.config/configurations/config_default
# /content/.config/config_sentinel
# /content/sample_data/anscombe.json
# /content/sample_data/README.md
# /content/sample_data/california_housing_test.csv
# /content/sample_data/california_housing_train.csv
# /content/sample_data/mnist_test.csv
# /content/sample_data/mnist_train_small.csv

# %%
# !unzip "lora_adapter (3).zip" -d .
# Out:
# unzip:  cannot find or open lora_adapter (3).zip, lora_adapter (3).zip.zip or lora_adapter (3).zip.ZIP.

# %%
# !ls -la "lora_adapter (3).zip"
# Out:
# ls: cannot access 'lora_adapter (3).zip': No such file or directory

# %%
# !file "lora_adapter (3).zip"
# Out:
# lora_adapter (3).zip: cannot open `lora_adapter (3).zip' (No such file or directory)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cp "/content/drive/MyDrive/lora_adapter (3).zip" .

# %%
# !unzip "lora_adapter (3).zip" -d .
# Out:
# Archive:  lora_adapter (3).zip
#    creating: ./lora_adapter/
#   inflating: ./lora_adapter/chat_template.jinja
#   inflating: ./lora_adapter/adapter_config.json
#   inflating: ./lora_adapter/README.md
#   inflating: ./lora_adapter/tokenizer.json
#   inflating: ./lora_adapter/tokenizer_config.json
#   inflating: ./lora_adapter/adapter_model.safetensors

# %%
# !file "/content/lora_adapter (3).zip"
# Out:
# /content/lora_adapter (3).zip: Zip archive data, at least v1.0 to extract, compression method=store

# %%
# !unzip -o "/content/lora_adapter (3).zip" -d "/content/lora_adapter_extracted"
# Out:
# Archive:  /content/lora_adapter (3).zip
#    creating: /content/lora_adapter_extracted/lora_adapter/
#   inflating: /content/lora_adapter_extracted/lora_adapter/chat_template.jinja
#   inflating: /content/lora_adapter_extracted/lora_adapter/adapter_config.json
#   inflating: /content/lora_adapter_extracted/lora_adapter/README.md
#   inflating: /content/lora_adapter_extracted/lora_adapter/tokenizer.json
#   inflating: /content/lora_adapter_extracted/lora_adapter/tokenizer_config.json
#   inflating: /content/lora_adapter_extracted/lora_adapter/adapter_model.safetensors

# %%
from unsloth import FastLanguageModel

model, tokenizer = FastLanguageModel.from_pretrained(
    model_name="lora_adapter",
    max_seq_length=2048,
    dtype=None,
    load_in_4bit=True,
)

FastLanguageModel.for_inference(model)
print("Model loaded and ready.")
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# ==((====))==  Unsloth 2026.9.5: Fast Llama patching. Transformers: 5.5.0.
#    \\   /|    Tesla T4. Num GPUs = 1. Max memory: 14.563 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.11.0+cu128. CUDA: 7.5. CUDA Toolkit: 12.8. Triton: 3.6.0
# \        /    Bfloat16 = FALSE. FA [Xformers = 0.0.35. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# Loading weights:   0%|          | 0/291 [00:00<?, ?it/s]
# Unsloth: Will load lora_adapter as a legacy tokenizer.
# Not an error, but Unsloth cannot patch MLP layers with our manual autograd engine since either LoRA adapters
# are not enabled or a bias term (like in Qwen) is used.
# Unsloth 2026.9.5 patched 32 layers with 32 QKV layers, 32 O layers and 0 MLP layers.
# Model loaded and ready.

# %%
print(model)
# Out:
# PeftModelForCausalLM(
#   (base_model): LoraModel(
#     (model): LlamaForCausalLM(
#       (model): LlamaModel(
#         (embed_tokens): Embedding(128256, 4096, padding_idx=128255)
#         (layers): ModuleList(
#           (0-31): 32 x LlamaDecoderLayer(
#             (self_attn): LlamaAttention(
#               (q_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=4096, out_features=4096, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Identity()
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=4096, out_features=16, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=16, out_features=4096, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (k_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=4096, out_features=1024, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Identity()
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=4096, out_features=16, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=16, out_features=1024, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (v_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=4096, out_features=1024, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Identity()
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=4096, out_features=16, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=16, out_features=1024, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (o_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=4096, out_features=4096, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Identity()
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=4096, out_features=16, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=16, out_features=4096, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (rotary_emb): LlamaRotaryEmbedding()
#             )
#             (mlp): LlamaMLP(
#               (gate_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (up_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (down_proj): Linear4bit(in_features=14336, out_features=4096, bias=False)
#               (act_fn): SiLUActivation()
#             )
#             (input_layernorm): LlamaRMSNorm((4096,), eps=1e-05)
#             (post_attention_layernorm): LlamaRMSNorm((4096,), eps=1e-05)
#           )
#         )
#         (norm): LlamaRMSNorm((4096,), eps=1e-05)
#         (rotary_emb): LlamaRotaryEmbedding()
#       )
#       (lm_head): Linear(in_features=4096, out_features=128256, bias=False)
#     )
#   )
# )

# %%
TEST_TICKETS = [
{"body": "User can't log in after password reset, getting 401 error.", "category": "auth", "urgency": "normal"},
{"body": "System is completely down, no one can access the app!", "category": "bug_report", "urgency": "critical"},
{"body": "Customer was charged twice for the same invoice.", "category": "billing", "urgency": "high"},
{"body": "Webhook stopped firing after we changed our endpoint URL", "category": "integration", "urgency": "normal"},
{"body": "Can you add dark mode to the dashboard?", "category": "feature_request", "urgency": "low"},
{"body": "I need to update the billing email on my account", "category": "account_management", "urgency": "low"},
{"body": "Dashboard takes over 30 seconds to load every time.", "category": "performance", "urgency": "high"},
{"body": "Just wanted to say thanks, everything's working great.", "category": "general", "urgency": "low"},
{"body": "API rate limit hit unexpectedly despite low usage.", "category": "integration", "urgency": "normal"},
{"body": "My account got locked out and I can't reset the password.", "category": "auth", "urgency": "high"},

 # --- auth ---
    {"body": "Two-factor authentication codes aren't arriving via SMS.", "category": "auth", "urgency": "high"},
    {"body": "I forgot my password and the reset email never showed up.", "category": "auth", "urgency": "normal"},
    {"body": "Someone else may have accessed my account without permission.", "category": "auth", "urgency": "critical"},

    # --- billing ---
    {"body": "My subscription renewed at the wrong price this month.", "category": "billing", "urgency": "normal"},
    {"body": "Can I get a copy of last year's invoices for tax purposes?", "category": "billing", "urgency": "low"},
    {"body": "Payment failed three times and now my account is suspended.", "category": "billing", "urgency": "critical"},

    # --- integration ---
    {"body": "Our Slack integration hasn't posted any updates in two days.", "category": "integration", "urgency": "high"},
    {"body": "Is there a way to connect this to our internal CRM via API?", "category": "integration", "urgency": "low"},
    {"body": "OAuth token keeps expiring every hour instead of every month.", "category": "integration", "urgency": "normal"},

    # --- bug_report ---
    {"body": "Clicking export crashes the whole browser tab.", "category": "bug_report", "urgency": "high"},
    {"body": "Search results show duplicate entries sometimes.", "category": "bug_report", "urgency": "normal"},
    {"body": "All uploaded files from last week have disappeared entirely.", "category": "bug_report", "urgency": "critical"},

    # --- feature_request ---
    {"body": "Would be great to have keyboard shortcuts for common actions.", "category": "feature_request", "urgency": "low"},
    {"body": "Any roadmap plans for a mobile app version?", "category": "feature_request", "urgency": "low"},

    # --- account_management ---
    {"body": "How do I add a new team member to our workspace?", "category": "account_management", "urgency": "normal"},
    {"body": "Please permanently delete my account and all associated data.", "category": "account_management", "urgency": "normal"},

    # --- performance ---
    {"body": "Reports have been timing out for the past hour, this is blocking our team.", "category": "performance", "urgency": "critical"},
    {"body": "Page load feels a little slower than usual lately.", "category": "performance", "urgency": "low"},

    # --- general ---
    {"body": "Do you have a status page I can check for outages?", "category": "general", "urgency": "low"},
    {"body": "Quick question, not urgent: where can I find your changelog?", "category": "general", "urgency": "low"},
]


print(f"loaded {len(TEST_TICKETS)} test tickets.")
# Out:
# loaded 30 test tickets.

# %%
import time
import json
import ast

SYSTEM_PROMPT = """You are a support ticket classifier.
Classify the ticket into exactly one category from: ['auth', 'billing', 'integration', 'bug_report', 'feature_request', 'account_management', 'performance', 'general']
And exactly one urgency level from: ['low', 'normal', 'high', 'critical']
Respond ONLY with JSON in this exact format, no other text:
{"category": "...", "urgency": "..."}"""


def classify_ticket(body):
    start = time.time()
    messages = [
        {"role": "system", "content": SYSTEM_PROMPT},
        {"role": "user", "content": body},
    ]
    prompt = tokenizer.apply_chat_template(messages, tokenize=False, add_generation_prompt=True)
    inputs = tokenizer(prompt, return_tensors="pt").to("cuda")

    output = model.generate(**inputs, max_new_tokens=50, temperature=0.01, do_sample=False)
    raw = tokenizer.decode(output[0][inputs["input_ids"].shape[1]:], skip_special_tokens=True).strip()

    latency_ms = (time.time() - start) * 1000

    try:
        parsed = json.loads(raw)
    except json.JSONDecodeError:
        try:
            parsed = ast.literal_eval(raw)
        except (ValueError, SyntaxError):
            parsed = {"category": "general", "urgency": "normal"}

    return {
        "category": parsed.get("category", "general"),
        "urgency": parsed.get("urgency", "normal"),
        "latency_ms": latency_ms,
    }

print("classify_ticket ready.")
# Out:
# classify_ticket ready.

# %%
results = []
correct_category = 0
correct_urgency = 0
total_latency = 0

for ticket in TEST_TICKETS:
    prediction = classify_ticket(ticket["body"])
    is_cat = prediction["category"] == ticket["category"]
    is_urg = prediction["urgency"] == ticket["urgency"]
    correct_category += is_cat
    correct_urgency += is_urg
    total_latency += prediction["latency_ms"]
    results.append({
        "body": ticket["body"],
        "expected": {"category": ticket["category"], "urgency": ticket["urgency"]},
        "predicted": {"category": prediction["category"], "urgency": prediction["urgency"]},
        "category_correct": is_cat,
        "urgency_correct": is_urg,
        "latency_ms": round(prediction["latency_ms"], 1),
    })
    print(f"{'PASS' if is_cat and is_urg else 'FAIL'} expected={ticket} predicted={prediction}")

n = len(TEST_TICKETS)
summary = {
    "n_tickets": n,
    "category_accuracy": round(correct_category / n, 3),
    "urgency_accuracy": round(correct_urgency / n, 3),
    "avg_latency_ms": round(total_latency / n, 1),
    "estimated_cost_per_1k_requests_usd": 0.48,
}

print("\n=== SUMMARY ===")
print(json.dumps(summary, indent=2))
# Out:
# Both `max_new_tokens` (=50) and `max_length`(=8192) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=50) and `max_length`(=8192) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# PASS expected={'body': "User can't log in after password reset, getting 401 error.", 'category': 'auth', 'urgency': 'normal'} predicted={'category': 'auth', 'urgency': 'normal', 'latency_ms': 6226.360321044922}
# Both `max_new_tokens` (=50) and `max_length`(=8192) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# FAIL expected={'body': 'System is completely down, no one can access the app!', 'category': 'bug_report', 'urgency': 'critical'} predicted={'category': 'bug_report', 'urgency': 'high', 'latency_ms': 1058.3832263946533}
# Both `max_new_tokens` (=50) and `max_length`(=8192) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# FAIL expected={'body': 'Customer was charged twice for the same invoice.', 'category': 'billing', 'urgency': 'high'} predicted={'category': 'billing', 'urgency': 'normal', 'latency_ms': 1057.096004486084}
# Both `max_new_tokens` (=50) and `max_length`(=8192) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# PASS expected={'body': 'Webhook stopped firing after we changed our endpoint URL', 'category': 'integration', 'urgency': 'normal'} predicted={'category': 'integration', 'urgency': 'normal', 'latency_ms': 968.9099788665771}
# Both `max_new_tokens` (=50) and `max_length`(=8192) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# FAIL expected={'body': 'Can you add dark mode to the dashboard?', 'category': 'feature_request', 'urgency': 'low'} predicted={'category': 'feature_request', 'urgency': 'normal', 'latency_ms': 1053.278923034668}
# Both `max_new_tokens` (=50) and `max_length`(=8192) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# FAIL expected={'body': 'I need to update the billing email on my account', 'category': 'account_management', 'urgency': 'low'} predicted={'category': 'account_management', 'urgency': 'normal', 'latency_ms': 1048.0735301971436}
# Both `max_new_tokens` (=50) and `max_length`(=8192) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# FAIL expected={'body': 'Dashboard takes over 30 seconds to load every time.', 'category': 'performance', 'urgency': 'high'} predicted={'category': 'performance', 'urgency': 'normal', 'latency_ms': 984.9998950958252}
# Both `max_new_tokens` (=50) and `max_length`(=8192) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# FAIL expected={'body': "Just wanted to say thanks, everything's working great.", 'category': 'general', 'urgency': 'low'} predicted={'category': 'general', 'urgency': 'normal', 'latency_ms': 982.241153717041}
# Both `max_new_tokens` (=50) and `max_length`(=8192) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# FAIL expected={'body': 'API rate limit hit unexpectedly despite low usage.', 'category': 'integration', 'urgency': 'normal'} predicted={'category': 'performance', 'urgency': 'normal', 'latency_ms': 993.013858795166}
# Both `max_new_tokens` (=50) and `max_length`(=8192) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# FAIL expected={'body': "My account got locked out and I can't reset the password.", 'category': 'auth', 'urgency': 'high'} predicted={'category': 'auth', 'urgency': 'normal', 'latency_ms': 1229.5472621917725}
# Both `max_new_tokens` (=50) and `max_length`(=8192) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# FAIL expected={'body': "Two-factor authentication codes aren't arriving via SMS.", 'category': 'auth', 'urgency': 'high'} predicted={'category': 'auth', 'urgency': 'normal', 'latency_ms': 1204.533576965332}
# Both `max_new_tokens` (=50) and `max_length`(=8192) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# PASS expected={'body': 'I forgot my password and the reset email never showed up.', 'category': 'auth', 'urgency': 'normal'} predicted={'category': 'auth', 'urgency': 'normal', 'latency_ms': 1340.7258987426758}
# Both `max_new_tokens` (=50) and `max_length`(=8192) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# FAIL expected={'body': 'Someone else may have accessed my account without permission.', 'category': 'auth', 'urgency': 'critical'} predicted={'category': 'auth', 'urgency': 'normal', 'latency_ms': 1000.7789134979248}
# Both `max_new_tokens` (=50) and `max_length`(=8192) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# PASS expected={'body': 'My subscription renewed at the wrong price this month.', 'category': 'billing', 'urgency': 'normal'} predicted={'category': 'billing', 'urgency': 'normal', 'latency_ms': 1011.6252899169922}
# Both `max_new_tokens` (=50) and `max_length`(=8192) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# FAIL expected={'body': "Can I get a copy of last year's invoices for tax purposes?", 'category': 'billing', 'urgency': 'low'} predicted={'category': 'billing', 'urgency': 'normal', 'latency_ms': 972.4287986755371}
# Both `max_new_tokens` (=50) and `max_length`(=8192) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# FAIL expected={'body': 'Payment failed three times and now my account is suspended.', 'category': 'billing', 'urgency': 'critical'} predicted={'category': 'billing', 'urgency': 'normal', 'latency_ms': 981.6091060638428}
# Both `max_new_tokens` (=50) and `max_length`(=8192) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# FAIL expected={'body': "Our Slack integration hasn't posted any updates in two days.", 'category': 'integration', 'urgency': 'high'} predicted={'category': 'integration', 'urgency': 'normal', 'latency_ms': 992.5305843353271}
# Both `max_new_tokens` (=50) and `max_length`(=8192) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# FAIL expected={'body': 'Is there a way to connect this to our internal CRM via API?', 'category': 'integration', 'urgency': 'low'} predicted={'category': 'integration', 'urgency': 'normal', 'latency_ms': 967.2598838806152}
# Both `max_new_tokens` (=50) and `max_length`(=8192) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# FAIL expected={'body': 'OAuth token keeps expiring every hour instead of every month.', 'category': 'integration', 'urgency': 'normal'} predicted={'category': 'auth', 'urgency': 'normal', 'latency_ms': 988.8262748718262}
# Both `max_new_tokens` (=50) and `max_length`(=8192) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# FAIL expected={'body': 'Clicking export crashes the whole browser tab.', 'category': 'bug_report', 'urgency': 'high'} predicted={'category': 'bug_report', 'urgency': 'normal', 'latency_ms': 1041.1815643310547}
# Both `max_new_tokens` (=50) and `max_length`(=8192) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# PASS expected={'body': 'Search results show duplicate entries sometimes.', 'category': 'bug_report', 'urgency': 'normal'} predicted={'category': 'bug_report', 'urgency': 'normal', 'latency_ms': 1041.130542755127}
# Both `max_new_tokens` (=50) and `max_length`(=8192) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# FAIL expected={'body': 'All uploaded files from last week have disappeared entirely.', 'category': 'bug_report', 'urgency': 'critical'} predicted={'category': 'bug_report', 'urgency': 'normal', 'latency_ms': 1086.3356590270996}
# Both `max_new_tokens` (=50) and `max_length`(=8192) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# FAIL expected={'body': 'Would be great to have keyboard shortcuts for common actions.', 'category': 'feature_request', 'urgency': 'low'} predicted={'category': 'feature_request', 'urgency': 'normal', 'latency_ms': 1295.811414718628}
# Both `max_new_tokens` (=50) and `max_length`(=8192) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# FAIL expected={'body': 'Any roadmap plans for a mobile app version?', 'category': 'feature_request', 'urgency': 'low'} predicted={'category': 'feature_request', 'urgency': 'normal', 'latency_ms': 1339.9829864501953}
# Both `max_new_tokens` (=50) and `max_length`(=8192) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# PASS expected={'body': 'How do I add a new team member to our workspace?', 'category': 'account_management', 'urgency': 'normal'} predicted={'category': 'account_management', 'urgency': 'normal', 'latency_ms': 1318.2942867279053}
# Both `max_new_tokens` (=50) and `max_length`(=8192) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# PASS expected={'body': 'Please permanently delete my account and all associated data.', 'category': 'account_management', 'urgency': 'normal'} predicted={'category': 'account_management', 'urgency': 'normal', 'latency_ms': 1058.9072704315186}
# Both `max_new_tokens` (=50) and `max_length`(=8192) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# FAIL expected={'body': 'Reports have been timing out for the past hour, this is blocking our team.', 'category': 'performance', 'urgency': 'critical'} predicted={'category': 'performance', 'urgency': 'high', 'latency_ms': 1026.7846584320068}
# Both `max_new_tokens` (=50) and `max_length`(=8192) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# FAIL expected={'body': 'Page load feels a little slower than usual lately.', 'category': 'performance', 'urgency': 'low'} predicted={'category': 'performance', 'urgency': 'normal', 'latency_ms': 998.4180927276611}
# Both `max_new_tokens` (=50) and `max_length`(=8192) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# FAIL expected={'body': 'Do you have a status page I can check for outages?', 'category': 'general', 'urgency': 'low'} predicted={'category': 'general', 'urgency': 'normal', 'latency_ms': 993.6962127685547}
# FAIL expected={'body': 'Quick question, not urgent: where can I find your changelog?', 'category': 'general', 'urgency': 'low'} predicted={'category': 'general', 'urgency': 'normal', 'latency_ms': 1005.0015449523926}
#
# === SUMMARY ===
# {
#   "n_tickets": 30,
#   "category_accuracy": 0.933,
#   "urgency_accuracy": 0.3,
#   "avg_latency_ms": 1242.3,
#   "estimated_cost_per_1k_requests_usd": 0.48
# }

# %%
with open("finetuned_results.json", "w") as f:
    json.dump({"summary": summary, "results": results}, f, indent=2)

from google.colab import files
files.download("finetuned_results.json")

# %% [markdown]
# **ONE FINAL RETRAINING WITH A SPLIT OF THE CATEGORIES AND THE URGENCY CLASSIFICATION.**
#
# **Urgency has been producing lesser signals because it has been smaller**

# %%
# !pip install unsloth wandb
# Out:
# Requirement already satisfied: unsloth in /usr/local/lib/python3.13/dist-packages (2026.9.5)
# Requirement already satisfied: wandb in /usr/local/lib/python3.13/dist-packages (0.28.1)
# Requirement already satisfied: unsloth_zoo>=2026.9.4 in /usr/local/lib/python3.13/dist-packages (from unsloth) (2026.9.4)
# Requirement already satisfied: wheel>=0.42.0 in /usr/local/lib/python3.13/dist-packages (from unsloth) (0.48.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.13/dist-packages (from unsloth) (26.3)
# Requirement already satisfied: torch<2.13.0,>=2.4.0 in /usr/local/lib/python3.13/dist-packages (from unsloth) (2.11.0+cu128)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.13/dist-packages (from unsloth) (0.26.0+cu128)
# Requirement already satisfied: numpy in /usr/local/lib/python3.13/dist-packages (from unsloth) (2.1.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.13/dist-packages (from unsloth) (4.67.3)
# Requirement already satisfied: psutil in /usr/local/lib/python3.13/dist-packages (from unsloth) (5.9.5)
# Requirement already satisfied: tyro in /usr/local/lib/python3.13/dist-packages (from unsloth) (1.0.16)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.13/dist-packages (from unsloth) (5.29.6)
# Requirement already satisfied: xformers>=0.0.27.post2 in /usr/local/lib/python3.13/dist-packages (from unsloth) (0.0.35)
# Requirement already satisfied: bitsandbytes!=0.46.0,!=0.48.0,>=0.45.5 in /usr/local/lib/python3.13/dist-packages (from unsloth) (0.50.2)
# Requirement already satisfied: triton>=3.0.0 in /usr/local/lib/python3.13/dist-packages (from unsloth) (3.6.0)
# Requirement already satisfied: sentencepiece>=0.2.0 in /usr/local/lib/python3.13/dist-packages (from unsloth) (0.2.2)
# Requirement already satisfied: datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1 in /usr/local/lib/python3.13/dist-packages (from unsloth) (4.3.0)
# Requirement already satisfied: accelerate>=0.34.1 in /usr/local/lib/python3.13/dist-packages (from unsloth) (1.14.0)
# Requirement already satisfied: peft!=0.11.0,>=0.18.0 in /usr/local/lib/python3.13/dist-packages (from unsloth) (0.20.0)
# Requirement already satisfied: huggingface_hub>=0.34.0 in /usr/local/lib/python3.13/dist-packages (from unsloth) (1.29.0)
# Requirement already satisfied: hf_transfer in /usr/local/lib/python3.13/dist-packages (from unsloth) (0.1.9)
# Requirement already satisfied: diffusers in /usr/local/lib/python3.13/dist-packages (from unsloth) (0.40.0)
# Requirement already satisfied: transformers!=4.52.0,!=4.52.1,!=4.52.2,!=4.52.3,!=4.53.0,!=4.54.0,!=4.55.0,!=4.55.1,!=4.57.0,!=4.57.4,!=4.57.5,!=5.0.0,!=5.1.0,<=5.5.0,>=4.51.3 in /usr/local/lib/python3.13/dist-packages (from unsloth) (5.5.0)
# Requirement already satisfied: trl!=0.19.0,<=0.24.0,>=0.18.2 in /usr/local/lib/python3.13/dist-packages (from unsloth) (0.24.0)
# Requirement already satisfied: typer>=0.12.0 in /usr/local/lib/python3.13/dist-packages (from unsloth) (0.27.2)
# Requirement already satisfied: pydantic in /usr/local/lib/python3.13/dist-packages (from unsloth) (2.13.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.13/dist-packages (from unsloth) (6.0.3)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.13/dist-packages (from unsloth) (1.6.0)
# Requirement already satisfied: structlog>=24.1.0 in /usr/local/lib/python3.13/dist-packages (from unsloth) (26.1.0)
# Requirement already satisfied: click>=8.0 in /usr/local/lib/python3.13/dist-packages (from unsloth) (8.5.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.13/dist-packages (from unsloth) (13.9.4)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.13/dist-packages (from wandb) (4.11.7)
# Requirement already satisfied: requests<3,>=2.0.0 in /usr/local/lib/python3.13/dist-packages (from wandb) (2.32.4)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /usr/local/lib/python3.13/dist-packages (from wandb) (2.68.1)
# Requirement already satisfied: typing-extensions<5,>=4.8 in /usr/local/lib/python3.13/dist-packages (from wandb) (4.16.0)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.13/dist-packages (from accelerate>=0.34.1->unsloth) (0.8.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.13/dist-packages (from datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth) (3.32.5)
# Requirement already satisfied: pyarrow>=21.0.0 in /usr/local/lib/python3.13/dist-packages (from datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth) (23.0.1)
# Requirement already satisfied: dill<0.4.1,>=0.3.0 in /usr/local/lib/python3.13/dist-packages (from datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth) (0.4.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.13/dist-packages (from datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth) (2.2.3)
# Requirement already satisfied: httpx<1.0.0 in /usr/local/lib/python3.13/dist-packages (from datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth) (0.28.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.13/dist-packages (from datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth) (4.0.1)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.13/dist-packages (from datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth) (0.70.16)
# Requirement already satisfied: fsspec<=2025.9.0,>=2023.1.0 in /usr/local/lib/python3.13/dist-packages (from fsspec[http]<=2025.9.0,>=2023.1.0->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth) (2025.9.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.5.2 in /usr/local/lib/python3.13/dist-packages (from huggingface_hub>=0.34.0->unsloth) (1.6.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.13/dist-packages (from pydantic->unsloth) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.5 in /usr/local/lib/python3.13/dist-packages (from pydantic->unsloth) (2.46.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.13/dist-packages (from pydantic->unsloth) (0.4.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.13/dist-packages (from requests<3,>=2.0.0->wandb) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.13/dist-packages (from requests<3,>=2.0.0->wandb) (3.19)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.13/dist-packages (from requests<3,>=2.0.0->wandb) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.13/dist-packages (from requests<3,>=2.0.0->wandb) (2026.7.22)
# Requirement already satisfied: setuptools<82 in /usr/local/lib/python3.13/dist-packages (from torch<2.13.0,>=2.4.0->unsloth) (80.10.2)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.13/dist-packages (from torch<2.13.0,>=2.4.0->unsloth) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.13/dist-packages (from torch<2.13.0,>=2.4.0->unsloth) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.13/dist-packages (from torch<2.13.0,>=2.4.0->unsloth) (3.1.6)
# Requirement already satisfied: cuda-toolkit==12.8.1 in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch<2.13.0,>=2.4.0->unsloth) (12.8.1)
# Requirement already satisfied: cuda-bindings<13,>=12.9.4 in /usr/local/lib/python3.13/dist-packages (from torch<2.13.0,>=2.4.0->unsloth) (12.9.7)
# Requirement already satisfied: nvidia-cudnn-cu12==9.19.0.56 in /usr/local/lib/python3.13/dist-packages (from torch<2.13.0,>=2.4.0->unsloth) (9.19.0.56)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.13/dist-packages (from torch<2.13.0,>=2.4.0->unsloth) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.28.9 in /usr/local/lib/python3.13/dist-packages (from torch<2.13.0,>=2.4.0->unsloth) (2.28.9)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.13/dist-packages (from torch<2.13.0,>=2.4.0->unsloth) (3.4.5)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch<2.13.0,>=2.4.0->unsloth) (12.8.4.1)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch<2.13.0,>=2.4.0->unsloth) (12.8.90)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch<2.13.0,>=2.4.0->unsloth) (11.3.3.83)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch<2.13.0,>=2.4.0->unsloth) (1.13.1.3)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch<2.13.0,>=2.4.0->unsloth) (12.8.90)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch<2.13.0,>=2.4.0->unsloth) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch<2.13.0,>=2.4.0->unsloth) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch<2.13.0,>=2.4.0->unsloth) (12.5.8.93)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch<2.13.0,>=2.4.0->unsloth) (12.8.93)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch<2.13.0,>=2.4.0->unsloth) (12.8.93)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch<2.13.0,>=2.4.0->unsloth) (12.8.90)
# Requirement already satisfied: regex>=2025.10.22 in /usr/local/lib/python3.13/dist-packages (from transformers!=4.52.0,!=4.52.1,!=4.52.2,!=4.52.3,!=4.53.0,!=4.54.0,!=4.55.0,!=4.55.1,!=4.57.0,!=4.57.4,!=4.57.5,!=5.0.0,!=5.1.0,<=5.5.0,>=4.51.3->unsloth) (2025.11.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.13/dist-packages (from transformers!=4.52.0,!=4.52.1,!=4.52.2,!=4.52.3,!=4.53.0,!=4.54.0,!=4.55.0,!=4.55.1,!=4.57.0,!=4.57.4,!=4.57.5,!=5.0.0,!=5.1.0,<=5.5.0,>=4.51.3->unsloth) (0.22.2)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.13/dist-packages (from typer>=0.12.0->unsloth) (1.5.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.13/dist-packages (from typer>=0.12.0->unsloth) (0.0.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.13/dist-packages (from rich->unsloth) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.13/dist-packages (from rich->unsloth) (2.21.0)
# Requirement already satisfied: torchao>=0.13.0 in /usr/local/lib/python3.13/dist-packages (from unsloth_zoo>=2026.9.4->unsloth) (0.18.0)
# Requirement already satisfied: cut_cross_entropy in /usr/local/lib/python3.13/dist-packages (from unsloth_zoo>=2026.9.4->unsloth) (25.1.1)
# Requirement already satisfied: pillow in /usr/local/lib/python3.13/dist-packages (from unsloth_zoo>=2026.9.4->unsloth) (11.3.0)
# Requirement already satisfied: msgspec in /usr/local/lib/python3.13/dist-packages (from unsloth_zoo>=2026.9.4->unsloth) (0.21.1)
# Requirement already satisfied: importlib_metadata in /usr/local/lib/python3.13/dist-packages (from diffusers->unsloth) (9.0.1)
# Requirement already satisfied: docstring-parser>=0.16 in /usr/local/lib/python3.13/dist-packages (from tyro->unsloth) (0.18.0)
# Requirement already satisfied: typeguard>=4.0.0 in /usr/local/lib/python3.13/dist-packages (from tyro->unsloth) (4.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.13/dist-packages (from cuda-bindings<13,>=12.9.4->torch<2.13.0,>=2.4.0->unsloth) (1.8.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.13/dist-packages (from fsspec[http]<=2025.9.0,>=2023.1.0->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth) (3.14.3)
# Requirement already satisfied: anyio in /usr/local/lib/python3.13/dist-packages (from httpx<1.0.0->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth) (4.14.2)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.13/dist-packages (from httpx<1.0.0->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.13/dist-packages (from httpcore==1.*->httpx<1.0.0->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth) (0.16.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.13/dist-packages (from markdown-it-py>=2.2.0->rich->unsloth) (0.1.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.13/dist-packages (from sympy>=1.13.3->torch<2.13.0,>=2.4.0->unsloth) (1.3.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.13/dist-packages (from importlib_metadata->diffusers->unsloth) (4.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.13/dist-packages (from jinja2->torch<2.13.0,>=2.4.0->unsloth) (3.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.13/dist-packages (from pandas->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.13/dist-packages (from pandas->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.13/dist-packages (from pandas->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth) (2026.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth) (2.7.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.13/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.13/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth) (1.24.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.13/dist-packages (from python-dateutil>=2.8.2->pandas->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth) (1.17.0)

# %%
# set up the weights and biases

import wandb
wandb.login()
# Out:
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice: 2
# wandb: You chose 'Use an existing W&B account'
# wandb: Logging into https://api.wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: Create a new API key at: https://wandb.ai/authorize?ref=models
# wandb: Store your API key securely and do not share it.
# wandb: Paste your API key and hit enter: ··········
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: paulajibola6 (paulajibola6-university-of-ibadan) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# True

# %%
# Load base model fresh

from unsloth import FastLanguageModel
import torch

# create tokenizer and model objects
model, tokenizer = FastLanguageModel.from_pretrained(
    model_name="unsloth/llama-3-8b-Instruct-bnb-4bit",
    max_seq_length=2048,
    dtype=None,
    load_in_4bit=True,
)
# Out:
# ==((====))==  Unsloth 2026.9.5: Fast Llama patching. Transformers: 5.5.0.
#    \\   /|    Tesla T4. Num GPUs = 1. Max memory: 14.563 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.11.0+cu128. CUDA: 7.5. CUDA Toolkit: 12.8. Triton: 3.6.0
# \        /    Bfloat16 = FALSE. FA [Xformers = 0.0.35. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# Loading weights:   0%|          | 0/291 [00:00<?, ?it/s]
# Unsloth: Will load unsloth/llama-3-8b-Instruct-bnb-4bit as a legacy tokenizer.

# %%
# apply the LoRA

model = FastLanguageModel.get_peft_model(
    model,
    r=16,
    lora_alpha=32,
    target_modules=["q_proj", "k_proj", "v_proj", "o_proj"],
    lora_dropout=0,
    bias="none",
    use_gradient_checkpointing=True,
)

# %%
# load the new split dataset

from datasets import load_dataset

dataset = load_dataset("json", data_files="/content/drive/MyDrive/training_data_split_formatted.jsonl", split="train")

def formatting_func(example):
  return tokenizer.apply_chat_template(example["messages"], tokenize=False)


dataset = dataset.map(lambda x: {"text": formatting_func(x)})
print(f"Loaded {len(dataset)} training examples.")
# Out:
# Generating train split: 0 examples [00:00, ? examples/s]
# Map:   0%|          | 0/1920 [00:00<?, ? examples/s]
# Loaded 1920 training examples.

# %%
# initialize the wandb and train

wandb.init(project="support-triage-lora", name="llama3-8b-r16-a32-v5-split-tasks")

from trl import SFTTrainer
from transformers import TrainingArguments



trainer = SFTTrainer(
    model=model,
    tokenizer=tokenizer,
    train_dataset=dataset,
    dataset_text_field="text",
    max_seq_length=2048,
    args=TrainingArguments(
        per_device_train_batch_size=4,
        gradient_accumulation_steps=4,
        warmup_steps=10,
        num_train_epochs=4,
        learning_rate=2e-4,
        logging_steps=5,
        output_dir="outputs",
        report_to="wandb",
        save_strategy="epoch",
    )
)

trainer.train()
# Out:
# wandb: W&B API key is configured. Use `wandb login --relogin` to force relogin
# Finishing previous runs because reinit is set to 'default'.
#  View run <strong style="color:#cdcd00">llama3-8b-r16-a32-v5-split-tasks</strong> at: <a href='https://wandb.ai/paulajibola6-university-of-ibadan/support-triage-lora/runs/ww12541b' target="_blank">https://wandb.ai/paulajibola6-university-of-ibadan/support-triage-lora/runs/ww12541b</a><br> View project at: <a href='https://wandb.ai/paulajibola6-university-of-ibadan/support-triage-lora' target="_blank">https://wandb.ai/paulajibola6-university-of-ibadan/support-triage-lora</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260916_200446-ww12541b/logs</code>
# Tracking run with wandb version 0.28.1
# Run data is saved locally in <code>/content/wandb/run-20260916_200508-qcxxtysz</code>
# Syncing run <strong><a href='https://wandb.ai/paulajibola6-university-of-ibadan/support-triage-lora/runs/qcxxtysz' target="_blank">llama3-8b-r16-a32-v5-split-tasks</a></strong> to <a href='https://wandb.ai/paulajibola6-university-of-ibadan/support-triage-lora' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/paulajibola6-university-of-ibadan/support-triage-lora' target="_blank">https://wandb.ai/paulajibola6-university-of-ibadan/support-triage-lora</a>
#  View run at <a href='https://wandb.ai/paulajibola6-university-of-ibadan/support-triage-lora/runs/qcxxtysz' target="_blank">https://wandb.ai/paulajibola6-university-of-ibadan/support-triage-lora/runs/qcxxtysz</a>
# Unsloth: We found double BOS tokens - we shall remove one automatically.
# Unsloth: Tokenizing ["text"] (num_proc=2):   0%|          | 0/1920 [00:00<?, ? examples/s]
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs used = 1
#    \\   /|    Num examples = 1,920 | Num Epochs = 4 | Total steps = 480
# O^O/ \_/ \    Batch size per device = 4 | Gradient accumulation steps = 4
# \        /    Data Parallel GPUs = 1 | Total batch size (4 x 4 x 1) = 16
#  "-____-"     Trainable parameters = 13,631,488 of 8,043,892,736 (0.17% trained)
# `use_return_dict` is deprecated! Use `return_dict` instead!
#     <div>
#
#       <progress value='480' max='480' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [480/480 45:00, Epoch 4/4]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>5</td>
#       <td>3.675589</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>2.468999</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>1.020119</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.569188</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.471238</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.394490</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>0.322999</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.279570</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>0.243265</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>0.227148</td>
#     </tr>
#     <tr>
#       <td>55</td>
#       <td>0.222474</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>0.206149</td>
#     </tr>
#     <tr>
#       <td>65</td>
#       <td>0.203347</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>0.184176</td>
#     </tr>
#     <tr>
#       <td>75</td>
#       <td>0.181451</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>0.146522</td>
#     </tr>
#     <tr>
#       <td>85</td>
#       <td>0.095516</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>0.077607</td>
#     </tr>
#     <tr>
#       <td>95</td>
#       <td>0.077146</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>0.078455</td>
#     </tr>
#     <tr>
#       <td>105</td>
#       <td>0.077132</td>
#     </tr>
#     <tr>
#       <td>110</td>
#       <td>0.078370</td>
#     </tr>
#     <tr>
#       <td>115</td>
#       <td>0.074009</td>
#     </tr>
#     <tr>
#       <td>120</td>
#       <td>0.077226</td>
#     </tr>
#     <tr>
#       <td>125</td>
#       <td>0.075265</td>
#     </tr>
#     <tr>
#       <td>130</td>
#       <td>0.072629</td>
#     </tr>
#     <tr>
#       <td>135</td>
#       <td>0.075220</td>
#     </tr>
#     <tr>
#       <td>140</td>
#       <td>0.071808</td>
#     </tr>
#     <tr>
#       <td>145</td>
#       <td>0.071757</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>0.071595</td>
#     </tr>
#     <tr>
#       <td>155</td>
#       <td>0.068246</td>
#     </tr>
#     <tr>
#       <td>160</td>
#       <td>0.072930</td>
#     </tr>
#     <tr>
#       <td>165</td>
#       <td>0.073176</td>
#     </tr>
#     <tr>
#       <td>170</td>
#       <td>0.069324</td>
#     </tr>
#     <tr>
#       <td>175</td>
#       <td>0.067887</td>
#     </tr>
#     <tr>
#       <td>180</td>
#       <td>0.074268</td>
#     </tr>
#     <tr>
#       <td>185</td>
#       <td>0.072638</td>
#     </tr>
#     <tr>
#       <td>190</td>
#       <td>0.070869</td>
#     </tr>
#     <tr>
#       <td>195</td>
#       <td>0.068871</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>0.070766</td>
#     </tr>
#     <tr>
#       <td>205</td>
#       <td>0.068569</td>
#     </tr>
#     <tr>
#       <td>210</td>
#       <td>0.074432</td>
#     </tr>
#     <tr>
#       <td>215</td>
#       <td>0.069109</td>
#     </tr>
#     <tr>
#       <td>220</td>
#       <td>0.068118</td>
#     </tr>
#     <tr>
#       <td>225</td>
#       <td>0.070949</td>
#     </tr>
#     <tr>
#       <td>230</td>
#       <td>0.069916</td>
#     </tr>
#     <tr>
#       <td>235</td>
#       <td>0.071688</td>
#     </tr>
#     <tr>
#       <td>240</td>
#       <td>0.070404</td>
#     </tr>
#     <tr>
#       <td>245</td>
#       <td>0.066361</td>
#     </tr>
#     <tr>
#       <td>250</td>
#       <td>0.066213</td>
#     </tr>
#     <tr>
#       <td>255</td>
#       <td>0.067211</td>
#     </tr>
#     <tr>
#       <td>260</td>
#       <td>0.067117</td>
#     </tr>
#     <tr>
#       <td>265</td>
#       <td>0.071543</td>
#     </tr>
#     <tr>
#       <td>270</td>
#       <td>0.069952</td>
#     </tr>
#     <tr>
#       <td>275</td>
#       <td>0.066026</td>
#     </tr>
#     <tr>
#       <td>280</td>
#       <td>0.067843</td>
#     </tr>
#     <tr>
#       <td>285</td>
#       <td>0.068879</td>
#     </tr>
#     <tr>
#       <td>290</td>
#       <td>0.068637</td>
#     </tr>
#     <tr>
#       <td>295</td>
#       <td>0.068377</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>0.067845</td>
#     </tr>
#     <tr>
#       <td>305</td>
#       <td>0.071303</td>
#     </tr>
#     <tr>
#       <td>310</td>
#       <td>0.068727</td>
#     </tr>
#     <tr>
#       <td>315</td>
#       <td>0.067031</td>
#     </tr>
#     <tr>
#       <td>320</td>
#       <td>0.068084</td>
#     </tr>
#     <tr>
#       <td>325</td>
#       <td>0.067062</td>
#     </tr>
#     <tr>
#       <td>330</td>
#       <td>0.069312</td>
#     </tr>
#     <tr>
#       <td>335</td>
#       <td>0.066160</td>
#     </tr>
#     <tr>
#       <td>340</td>
#       <td>0.066876</td>
#     </tr>
#     <tr>
#       <td>345</td>
#       <td>0.067734</td>
#     </tr>
#     <tr>
#       <td>350</td>
#       <td>0.067189</td>
#     </tr>
#     <tr>
#       <td>355</td>
#       <td>0.065711</td>
#     </tr>
#     <tr>
#       <td>360</td>
#       <td>0.064304</td>
#     </tr>
#     <tr>
#       <td>365</td>
#       <td>0.064396</td>
#     </tr>
#     <tr>
#       <td>370</td>
#       <td>0.066977</td>
#     </tr>
#     <tr>
#       <td>375</td>
#       <td>0.068328</td>
#     </tr>
#     <tr>
#       <td>380</td>
#       <td>0.067049</td>
#     </tr>
#     <tr>
#       <td>385</td>
#       <td>0.065277</td>
#     </tr>
#     <tr>
#       <td>390</td>
#       <td>0.066688</td>
#     </tr>
#     <tr>
#       <td>395</td>
#       <td>0.063912</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>0.067658</td>
#     </tr>
#     <tr>
#       <td>405</td>
#       <td>0.062904</td>
#     </tr>
#     <tr>
#       <td>410</td>
#       <td>0.065809</td>
#     </tr>
#     <tr>
#       <td>415</td>
#       <td>0.067834</td>
#     </tr>
#     <tr>
#       <td>420</td>
#       <td>0.065109</td>
#     </tr>
#     <tr>
#       <td>425</td>
#       <td>0.067963</td>
#     </tr>
#     <tr>
#       <td>430</td>
#       <td>0.066055</td>
#     </tr>
#     <tr>
#       <td>435</td>
#       <td>0.067206</td>
#     </tr>
#     <tr>
#       <td>440</td>
#       <td>0.063904</td>
#     </tr>
#     <tr>
#       <td>445</td>
#       <td>0.063993</td>
#     </tr>
#     <tr>
#       <td>450</td>
#       <td>0.066237</td>
#     </tr>
#     <tr>
#       <td>455</td>
#       <td>0.065074</td>
#     </tr>
#     <tr>
#       <td>460</td>
#       <td>0.065129</td>
#     </tr>
#     <tr>
#       <td>465</td>
#       <td>0.066268</td>
#     </tr>
#     <tr>
#       <td>470</td>
#       <td>0.067452</td>
#     </tr>
#     <tr>
#       <td>475</td>
#       <td>0.067102</td>
#     </tr>
#     <tr>
#       <td>480</td>
#       <td>0.063718</td>
#     </tr>
#   </tbody>
# </table><p>
# Unsloth: Restored added_tokens_decoder metadata in outputs/checkpoint-120/tokenizer_config.json.
# Unsloth: Restored added_tokens_decoder metadata in outputs/checkpoint-240/tokenizer_config.json.
# Unsloth: Restored added_tokens_decoder metadata in outputs/checkpoint-360/tokenizer_config.json.
# Unsloth: Restored added_tokens_decoder metadata in outputs/checkpoint-480/tokenizer_config.json.
# TrainOutput(global_step=480, training_loss=0.1705225182697177, metrics={'train_runtime': 2715.2043, 'train_samples_per_second': 2.829, 'train_steps_per_second': 0.177, 'total_flos': 3.287840549388288e+16, 'train_loss': 0.1705225182697177, 'epoch': 4.0})

# %%
# save the adapter
model.save_pretrained("lora_adapter_v6")
tokenizer.save_pretrained("lora_adapter_v6")
# Out:
# Unsloth: Restored added_tokens_decoder metadata in lora_adapter_v6/tokenizer_config.json.
# ('lora_adapter_v6/tokenizer_config.json',
#  'lora_adapter_v6/chat_template.jinja',
#  'lora_adapter_v6/tokenizer.json')

# %%
TEST_TICKETS = [
{"body": "User can't log in after password reset, getting 401 error.", "category": "auth", "urgency": "normal"},
{"body": "System is completely down, no one can access the app!", "category": "bug_report", "urgency": "critical"},
{"body": "Customer was charged twice for the same invoice.", "category": "billing", "urgency": "high"},
{"body": "Webhook stopped firing after we changed our endpoint URL", "category": "integration", "urgency": "normal"},
{"body": "Can you add dark mode to the dashboard?", "category": "feature_request", "urgency": "low"},
{"body": "I need to update the billing email on my account", "category": "account_management", "urgency": "low"},
{"body": "Dashboard takes over 30 seconds to load every time.", "category": "performance", "urgency": "high"},
{"body": "Just wanted to say thanks, everything's working great.", "category": "general", "urgency": "low"},
{"body": "API rate limit hit unexpectedly despite low usage.", "category": "integration", "urgency": "normal"},
{"body": "My account got locked out and I can't reset the password.", "category": "auth", "urgency": "high"},

 # --- auth ---
    {"body": "Two-factor authentication codes aren't arriving via SMS.", "category": "auth", "urgency": "high"},
    {"body": "I forgot my password and the reset email never showed up.", "category": "auth", "urgency": "normal"},
    {"body": "Someone else may have accessed my account without permission.", "category": "auth", "urgency": "critical"},

    # --- billing ---
    {"body": "My subscription renewed at the wrong price this month.", "category": "billing", "urgency": "normal"},
    {"body": "Can I get a copy of last year's invoices for tax purposes?", "category": "billing", "urgency": "low"},
    {"body": "Payment failed three times and now my account is suspended.", "category": "billing", "urgency": "critical"},

    # --- integration ---
    {"body": "Our Slack integration hasn't posted any updates in two days.", "category": "integration", "urgency": "high"},
    {"body": "Is there a way to connect this to our internal CRM via API?", "category": "integration", "urgency": "low"},
    {"body": "OAuth token keeps expiring every hour instead of every month.", "category": "integration", "urgency": "normal"},

    # --- bug_report ---
    {"body": "Clicking export crashes the whole browser tab.", "category": "bug_report", "urgency": "high"},
    {"body": "Search results show duplicate entries sometimes.", "category": "bug_report", "urgency": "normal"},
    {"body": "All uploaded files from last week have disappeared entirely.", "category": "bug_report", "urgency": "critical"},

    # --- feature_request ---
    {"body": "Would be great to have keyboard shortcuts for common actions.", "category": "feature_request", "urgency": "low"},
    {"body": "Any roadmap plans for a mobile app version?", "category": "feature_request", "urgency": "low"},

    # --- account_management ---
    {"body": "How do I add a new team member to our workspace?", "category": "account_management", "urgency": "normal"},
    {"body": "Please permanently delete my account and all associated data.", "category": "account_management", "urgency": "normal"},

    # --- performance ---
    {"body": "Reports have been timing out for the past hour, this is blocking our team.", "category": "performance", "urgency": "critical"},
    {"body": "Page load feels a little slower than usual lately.", "category": "performance", "urgency": "low"},

    # --- general ---
    {"body": "Do you have a status page I can check for outages?", "category": "general", "urgency": "low"},
    {"body": "Quick question, not urgent: where can I find your changelog?", "category": "general", "urgency": "low"},
]


print(f"loaded {len(TEST_TICKETS)} test tickets.")
# Out:
# loaded 30 test tickets.

# %%
import time
import json
import ast
from typing import Dict, Any

SYSTEM_PROMPT = """You are a support ticket classifier.
Classify the ticket into exactly one category from: ['auth', 'billing', 'integration', 'bug_report', 'feature_request', 'account_management', 'performance', 'general']
And exactly one urgency level from: ['low', 'normal', 'high', 'critical']
Respond ONLY with JSON in this exact format, no other text:
{"category": "...", "urgency": "..."}"""


def classify_ticket(body: str) -> Dict[str, Any]:
    start = time.time()
    messages = [
        # system instructions for classification [how to function and behave]
        {"role": "system", "content": SYSTEM_PROMPT},
        # user-provided supprt ticket
        {"role": "user", "content": body},
    ]
    # generate formatted style for action, not tokenize, yet!
    prompt = tokenizer.apply_chat_template(messages, tokenize=False, add_generation_prompt=True)
    # 'pt' means pytorch tensors. Tokenize the prompt and pass to 'cuda'
    inputs = tokenizer(prompt, return_tensors="pt").to("cuda")

    output = model.generate(**inputs, max_new_tokens=50, temperature=0.01, do_sample=False)
    # convert from tokenizer back to text strings
    raw = tokenizer.decode(output[0][inputs["input_ids"].shape[1]:], skip_special_tokens=True).strip()

    latency_ms = (time.time() - start) * 1000

    try:
        parsed = json.loads(raw)
    except json.JSONDecodeError:
        try:
            parsed = ast.literal_eval(raw)
        except (ValueError, SyntaxError):
            parsed = {"category": "general", "urgency": "normal"}

    return {
        "category": parsed.get("category", "general"),
        "urgency": parsed.get("urgency", "normal"),
        "latency_ms": latency_ms,
    }

print("classify_ticket ready.")
# Out:
# classify_ticket ready.

# %%
results = []
correct_category = 0
correct_urgency = 0
total_latency = 0

for ticket in TEST_TICKETS:
    prediction = classify_ticket(ticket["body"])
    is_cat = prediction["category"] == ticket["category"]
    is_urg = prediction["urgency"] == ticket["urgency"]
    correct_category += is_cat
    correct_urgency += is_urg
    total_latency += prediction["latency_ms"]
    results.append({
        "body": ticket["body"],
        "expected": {"category": ticket["category"], "urgency": ticket["urgency"]},
        "predicted": {"category": prediction["category"], "urgency": prediction["urgency"]},
        "category_correct": is_cat,
        "urgency_correct": is_urg,
        "latency_ms": round(prediction["latency_ms"], 1),
    })
    print(f"{'PASS' if is_cat and is_urg else 'FAIL'} expected={ticket} predicted={prediction}")

n = len(TEST_TICKETS)
summary = {
    "n_tickets": n,
    "category_accuracy": round(correct_category / n, 3),
    "urgency_accuracy": round(correct_urgency / n, 3),
    "avg_latency_ms": round(total_latency / n, 1),
    "estimated_cost_per_1k_requests_usd": 0.48,
}

print("\n=== SUMMARY ===")
print(json.dumps(summary, indent=2))
# Out:
# Both `max_new_tokens` (=50) and `max_length`(=8192) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=50) and `max_length`(=8192) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# FAIL expected={'body': "User can't log in after password reset, getting 401 error.", 'category': 'auth', 'urgency': 'normal'} predicted={'category': 'auth', 'urgency': 'high', 'latency_ms': 1083.1291675567627}
# Both `max_new_tokens` (=50) and `max_length`(=8192) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# FAIL expected={'body': 'System is completely down, no one can access the app!', 'category': 'bug_report', 'urgency': 'critical'} predicted={'category': 'performance', 'urgency': 'high', 'latency_ms': 1206.033706665039}
# Both `max_new_tokens` (=50) and `max_length`(=8192) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# PASS expected={'body': 'Customer was charged twice for the same invoice.', 'category': 'billing', 'urgency': 'high'} predicted={'category': 'billing', 'urgency': 'high', 'latency_ms': 1467.0300483703613}
# Both `max_new_tokens` (=50) and `max_length`(=8192) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# PASS expected={'body': 'Webhook stopped firing after we changed our endpoint URL', 'category': 'integration', 'urgency': 'normal'} predicted={'category': 'integration', 'urgency': 'normal', 'latency_ms': 974.1249084472656}
# Both `max_new_tokens` (=50) and `max_length`(=8192) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# PASS expected={'body': 'Can you add dark mode to the dashboard?', 'category': 'feature_request', 'urgency': 'low'} predicted={'category': 'feature_request', 'urgency': 'low', 'latency_ms': 1184.9353313446045}
# Both `max_new_tokens` (=50) and `max_length`(=8192) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# FAIL expected={'body': 'I need to update the billing email on my account', 'category': 'account_management', 'urgency': 'low'} predicted={'category': 'account_management', 'urgency': 'normal', 'latency_ms': 1297.177791595459}
# Both `max_new_tokens` (=50) and `max_length`(=8192) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# PASS expected={'body': 'Dashboard takes over 30 seconds to load every time.', 'category': 'performance', 'urgency': 'high'} predicted={'category': 'performance', 'urgency': 'high', 'latency_ms': 1243.9870834350586}
# Both `max_new_tokens` (=50) and `max_length`(=8192) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# PASS expected={'body': "Just wanted to say thanks, everything's working great.", 'category': 'general', 'urgency': 'low'} predicted={'category': 'general', 'urgency': 'low', 'latency_ms': 1311.9723796844482}
# Both `max_new_tokens` (=50) and `max_length`(=8192) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# FAIL expected={'body': 'API rate limit hit unexpectedly despite low usage.', 'category': 'integration', 'urgency': 'normal'} predicted={'category': 'performance', 'urgency': 'high', 'latency_ms': 1002.6066303253174}
# Both `max_new_tokens` (=50) and `max_length`(=8192) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# PASS expected={'body': "My account got locked out and I can't reset the password.", 'category': 'auth', 'urgency': 'high'} predicted={'category': 'auth', 'urgency': 'high', 'latency_ms': 989.6831512451172}
# Both `max_new_tokens` (=50) and `max_length`(=8192) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# PASS expected={'body': "Two-factor authentication codes aren't arriving via SMS.", 'category': 'auth', 'urgency': 'high'} predicted={'category': 'auth', 'urgency': 'high', 'latency_ms': 1003.1781196594238}
# Both `max_new_tokens` (=50) and `max_length`(=8192) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# PASS expected={'body': 'I forgot my password and the reset email never showed up.', 'category': 'auth', 'urgency': 'normal'} predicted={'category': 'auth', 'urgency': 'normal', 'latency_ms': 995.8944320678711}
# Both `max_new_tokens` (=50) and `max_length`(=8192) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# FAIL expected={'body': 'Someone else may have accessed my account without permission.', 'category': 'auth', 'urgency': 'critical'} predicted={'category': 'security', 'urgency': 'high', 'latency_ms': 996.4993000030518}
# Both `max_new_tokens` (=50) and `max_length`(=8192) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# PASS expected={'body': 'My subscription renewed at the wrong price this month.', 'category': 'billing', 'urgency': 'normal'} predicted={'category': 'billing', 'urgency': 'normal', 'latency_ms': 1000.7059574127197}
# Both `max_new_tokens` (=50) and `max_length`(=8192) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# PASS expected={'body': "Can I get a copy of last year's invoices for tax purposes?", 'category': 'billing', 'urgency': 'low'} predicted={'category': 'billing', 'urgency': 'low', 'latency_ms': 991.9512271881104}
# Both `max_new_tokens` (=50) and `max_length`(=8192) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# FAIL expected={'body': 'Payment failed three times and now my account is suspended.', 'category': 'billing', 'urgency': 'critical'} predicted={'category': 'billing', 'urgency': 'high', 'latency_ms': 1011.6672515869141}
# Both `max_new_tokens` (=50) and `max_length`(=8192) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# FAIL expected={'body': "Our Slack integration hasn't posted any updates in two days.", 'category': 'integration', 'urgency': 'high'} predicted={'category': 'integration', 'urgency': 'normal', 'latency_ms': 995.2001571655273}
# Both `max_new_tokens` (=50) and `max_length`(=8192) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# FAIL expected={'body': 'Is there a way to connect this to our internal CRM via API?', 'category': 'integration', 'urgency': 'low'} predicted={'category': 'integration', 'urgency': 'normal', 'latency_ms': 1033.653974533081}
# Both `max_new_tokens` (=50) and `max_length`(=8192) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# FAIL expected={'body': 'OAuth token keeps expiring every hour instead of every month.', 'category': 'integration', 'urgency': 'normal'} predicted={'category': 'integration', 'urgency': 'high', 'latency_ms': 1216.8653011322021}
# Both `max_new_tokens` (=50) and `max_length`(=8192) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# PASS expected={'body': 'Clicking export crashes the whole browser tab.', 'category': 'bug_report', 'urgency': 'high'} predicted={'category': 'bug_report', 'urgency': 'high', 'latency_ms': 1320.6043243408203}
# Both `max_new_tokens` (=50) and `max_length`(=8192) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# FAIL expected={'body': 'Search results show duplicate entries sometimes.', 'category': 'bug_report', 'urgency': 'normal'} predicted={'category': 'performance', 'urgency': 'normal', 'latency_ms': 1285.4077816009521}
# Both `max_new_tokens` (=50) and `max_length`(=8192) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# FAIL expected={'body': 'All uploaded files from last week have disappeared entirely.', 'category': 'bug_report', 'urgency': 'critical'} predicted={'category': 'bug_report', 'urgency': 'high', 'latency_ms': 1089.9879932403564}
# Both `max_new_tokens` (=50) and `max_length`(=8192) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# PASS expected={'body': 'Would be great to have keyboard shortcuts for common actions.', 'category': 'feature_request', 'urgency': 'low'} predicted={'category': 'feature_request', 'urgency': 'low', 'latency_ms': 1039.3507480621338}
# Both `max_new_tokens` (=50) and `max_length`(=8192) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# PASS expected={'body': 'Any roadmap plans for a mobile app version?', 'category': 'feature_request', 'urgency': 'low'} predicted={'category': 'feature_request', 'urgency': 'low', 'latency_ms': 1045.9699630737305}
# Both `max_new_tokens` (=50) and `max_length`(=8192) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# PASS expected={'body': 'How do I add a new team member to our workspace?', 'category': 'account_management', 'urgency': 'normal'} predicted={'category': 'account_management', 'urgency': 'normal', 'latency_ms': 1074.3563175201416}
# Both `max_new_tokens` (=50) and `max_length`(=8192) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# FAIL expected={'body': 'Please permanently delete my account and all associated data.', 'category': 'account_management', 'urgency': 'normal'} predicted={'category': 'account_management', 'urgency': 'low', 'latency_ms': 1089.827299118042}
# Both `max_new_tokens` (=50) and `max_length`(=8192) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# FAIL expected={'body': 'Reports have been timing out for the past hour, this is blocking our team.', 'category': 'performance', 'urgency': 'critical'} predicted={'category': 'performance', 'urgency': 'high', 'latency_ms': 990.553617477417}
# Both `max_new_tokens` (=50) and `max_length`(=8192) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# FAIL expected={'body': 'Page load feels a little slower than usual lately.', 'category': 'performance', 'urgency': 'low'} predicted={'category': 'performance', 'urgency': 'normal', 'latency_ms': 988.7535572052002}
# Both `max_new_tokens` (=50) and `max_length`(=8192) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# PASS expected={'body': 'Do you have a status page I can check for outages?', 'category': 'general', 'urgency': 'low'} predicted={'category': 'general', 'urgency': 'low', 'latency_ms': 982.4490547180176}
# PASS expected={'body': 'Quick question, not urgent: where can I find your changelog?', 'category': 'general', 'urgency': 'low'} predicted={'category': 'general', 'urgency': 'low', 'latency_ms': 998.9926815032959}
#
# === SUMMARY ===
# {
#   "n_tickets": 30,
#   "category_accuracy": 0.867,
#   "urgency_accuracy": 0.567,
#   "avg_latency_ms": 1097.1,
#   "estimated_cost_per_1k_requests_usd": 0.48
# }

# %%
with open("finetuned_results.json", "w") as f:
    json.dump({"summary": summary, "results": results}, f, indent=2)

from google.colab import files
files.download("finetuned_results.json")

# %%
# !zip -r lora_adapter_v6.zip lora_adapter_v6
from google.colab import files
files.download("lora_adapter_v6.zip")
# Out:
#   adding: lora_adapter_v6/ (stored 0%)
#   adding: lora_adapter_v6/adapter_config.json (deflated 59%)
#   adding: lora_adapter_v6/tokenizer.json (deflated 85%)
#   adding: lora_adapter_v6/adapter_model.safetensors (deflated 7%)
#   adding: lora_adapter_v6/chat_template.jinja (deflated 52%)
#   adding: lora_adapter_v6/README.md (deflated 65%)
#   adding: lora_adapter_v6/tokenizer_config.json (deflated 96%)

# %%
# Out:
# ls: cannot access 'eval/results/': No such file or directory
